# %%
import pandas as pd

# %%
df=pd.read_csv("undersampled_data.csv")
df
# Out:
#         User  Card    Year  Month   Day   Amount             UseChip  \
# 0     1750.0   0.0  2015.0    7.0  16.0   $21.42   Swipe Transaction
# 1     1959.0   1.0  2016.0    5.0   5.0   $76.99    Chip Transaction
# 2      182.0   2.0  2012.0   11.0  23.0    $2.19   Swipe Transaction
# 3      458.0   2.0  2019.0    5.0  15.0   $45.73    Chip Transaction
# 4     1949.0   0.0  2018.0    1.0   4.0    $1.25    Chip Transaction
# ...      ...   ...     ...    ...   ...      ...                 ...
# 1739  1998.0   2.0  2013.0    1.0  26.0  $193.24   Swipe Transaction
# 1740  1999.0   3.0  2020.0    1.0  26.0  $221.96   Swipe Transaction
# 1741  1999.0   3.0  2020.0    1.0  26.0   $26.69   Swipe Transaction
# 1742  1999.0   3.0  2020.0    1.0  26.0  $103.95    Chip Transaction
# 1743  1999.0   3.0  2020.0    1.0  26.0    $0.24  Online Transaction
#
#                                MerchantName MerchantCity MerchantState  \
# 0                           Lukass Theaters       Tiffin            OH
# 1                          Jadens Wholesale    Lancaster            CA
# 2                       Supermarket Chain 3      Houston            TX
# 3                       Supermarket Chain 3        Flint            MI
# 4                 Convenience Store Chain 1     Brooklyn            NY
# ...                                     ...          ...           ...
# 1739  Neufelder Tegucigalpa Wine and Liquor  Tegucigalpa      Honduras
# 1740                       Abrils Wholesale  Saint Louis            MO
# 1741                       Abrils Wholesale  Saint Louis            MO
# 1742             Cox Saint Louis Restaurant  Saint Louis            MO
# 1743              Digital Content Company 2       ONLINE            CA
#
#                Zip     MCC target
# 0     44883.000000  7832.0     No
# 1     93535.000000  5300.0     No
# 2     77096.000000  5411.0     No
# 3     48532.000000  5411.0     No
# 4     11213.000000  5499.0     No
# ...            ...     ...    ...
# 1739  51694.676895  5921.0    Yes
# 1740  63146.000000  5300.0    Yes
# 1741  63146.000000  5300.0    Yes
# 1742  63146.000000  5812.0    Yes
# 1743  51694.676895  5815.0    Yes
#
# [1744 rows x 13 columns]

# %%
df['Amount'] = df['Amount'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
col = ['UseChip', 'MerchantName', 'MerchantCity', 'MerchantState','target']
for i in col:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
independent=df[['User', 'Card', 'Year', 'Month', 'Day','UseChip','Amount',
       'MerchantName', 'MerchantCity', 'MerchantState', 'Zip', 'MCC']]

dependent=df[['target']]
independent
# Out:
#         User  Card    Year  Month   Day  UseChip  Amount  MerchantName  \
# 0     1750.0   0.0  2015.0    7.0  16.0        2   21.42           383
# 1     1959.0   1.0  2016.0    5.0   5.0        0   76.99           318
# 2      182.0   2.0  2012.0   11.0  23.0        2    2.19           529
# 3      458.0   2.0  2019.0    5.0  15.0        0   45.73           529
# 4     1949.0   0.0  2018.0    1.0   4.0        0    1.25           153
# ...      ...   ...     ...    ...   ...      ...     ...           ...
# 1739  1998.0   2.0  2013.0    1.0  26.0        2  193.24           422
# 1740  1999.0   3.0  2020.0    1.0  26.0        2  221.96            10
# 1741  1999.0   3.0  2020.0    1.0  26.0        2   26.69            10
# 1742  1999.0   3.0  2020.0    1.0  26.0        0  103.95           160
# 1743  1999.0   3.0  2020.0    1.0  26.0        1    0.24           193
#
#       MerchantCity  MerchantState           Zip     MCC
# 0              522             45  44883.000000  7832.0
# 1              270              6  93535.000000  5300.0
# 2              230             55  77096.000000  5411.0
# 3              171             31  48532.000000  5411.0
# 4               68             44  11213.000000  5499.0
# ...            ...            ...           ...     ...
# 1739           520             18  51694.676895  5921.0
# 1740           471             33  63146.000000  5300.0
# 1741           471             33  63146.000000  5300.0
# 1742           471             33  63146.000000  5812.0
# 1743           387              6  51694.676895  5815.0
#
# [1744 rows x 12 columns]

# %% [raw]
# #Check the correlation for balanced dataset
# #correlation -relationship between 2 variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(25,25))
sns.heatmap(df.corr(),annot=True,ax=ax)
plt.show()

# %% [raw]
# #Feature Selection

# %%
cor=df.corr()
cor_target=abs(cor["target"])
relevant_features=cor_target[cor_target>0.06]
print(relevant_features)
# Out:
# Year             0.091520
# Month            0.086224
# Amount           0.162054
# MerchantName     0.107166
# MerchantCity     0.184879
# MerchantState    0.144218
# MCC              0.070231
# target           1.000000
# Name: target, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np

# Create the ExtraTreesClassifier model
model = ExtraTreesClassifier()

# Fit the model on your data
model.fit(independent, dependent)

# Get feature importances
importances = model.feature_importances_

# Sort the feature importances in descending order
sorted_indices = np.argsort(importances)[::-1]

# Print feature importances
for i, index in enumerate(sorted_indices):
    print(f"{i + 1}. Feature: {independent.columns[index]} - Importance: {importances[index]}")
# Out:
# E:\Anaconda\envs\card\lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 1. Feature: Zip - Importance: 0.24446835165359396
# 2. Feature: MerchantState - Importance: 0.12943287143206791
# 3. Feature: MerchantCity - Importance: 0.1227931701170056
# 4. Feature: Year - Importance: 0.10476460682994256
# 5. Feature: MCC - Importance: 0.07462325612082925
# 6. Feature: MerchantName - Importance: 0.07453936269566391
# 7. Feature: Month - Importance: 0.049219243518916184
# 8. Feature: Amount - Importance: 0.048959510382012156
# 9. Feature: UseChip - Importance: 0.04244565038534281
# 10. Feature: User - Importance: 0.038216609123049874
# 11. Feature: Day - Importance: 0.03792717642594526
# 12. Feature: Card - Importance: 0.032610191315630616
